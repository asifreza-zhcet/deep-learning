# %% [markdown]
# # Customer churn Prediction using ANN

# %% [markdown]
# ## Loading the data

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\rezaa\Desktop\archive\Churn_Modelling.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## Checking if there is any null value

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Checking if there is any duplicated data

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# ## Deleting less important columns

# %%
data.drop(labels=['RowNumber', 'CustomerId', 'Surname'],axis = 1,inplace=True)

# %%
data
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %% [markdown]
# ## Converting categorical to numarical value using one hot encoding

# %%
data = pd.get_dummies(data, columns = ['Geography','Gender'],drop_first = True,dtype='int')

# %%
data
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# 1                  1        112542.58       0                  0
# 2                  0        113931.57       1                  0
# 3                  0         93826.63       0                  0
# 4                  1         79084.10       0                  0
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0                  0
# 9996               1        101699.77       0                  0
# 9997               1         42085.58       1                  0
# 9998               0         92888.52       1                  1
# 9999               0         38190.78       0                  0
#
#       Geography_Spain  Gender_Male
# 0                   0            0
# 1                   1            0
# 2                   0            0
# 3                   0            0
# 4                   1            0
# ...               ...          ...
# 9995                0            1
# 9996                0            1
# 9997                0            0
# 9998                0            1
# 9999                0            0
#
# [10000 rows x 12 columns]

# %%
X = data.drop(columns=['Exited']).values
y = data.loc[:,'Exited'].values

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 0)

# %% [markdown]
# # ANN model building

# %% [markdown]
# ## First create a Sequential object. This contains all the nodes

# %%
from tensorflow.keras import Sequential
model = Sequential()

# %% [markdown]
# ## In the squectial object add layers using Dense object

# %%
from tensorflow.keras.layers import Dense
model.add(Dense(11,activation='sigmoid',input_dim=11,name='layer_1'))
model.add(Dense(11,activation='sigmoid',name='layer_2'))
model.add(Dense(1,activation='sigmoid',name='output_layer'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer_1 (Dense)             (None, 11)                132
#
#  layer_2 (Dense)             (None, 11)                132
#
#  output_layer (Dense)        (None, 1)                 12
#
# =================================================================
# Total params: 276
# Trainable params: 276
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Using compile method to add loss function, optimizer for sgd and metrics to print during training

# %%
model.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=100,validation_split=0.20,verbose=1)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 4ms/step - loss: 1.0247 - accuracy: 0.2150 - val_loss: 0.6899 - val_accuracy: 0.5600
# Epoch 2/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5925 - accuracy: 0.7866 - val_loss: 0.5328 - val_accuracy: 0.7969
# Epoch 3/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5130 - accuracy: 0.7958 - val_loss: 0.4986 - val_accuracy: 0.7969
# Epoch 4/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4931 - accuracy: 0.7958 - val_loss: 0.4869 - val_accuracy: 0.7969
# Epoch 5/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4832 - accuracy: 0.7958 - val_loss: 0.4783 - val_accuracy: 0.7969
# Epoch 6/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4745 - accuracy: 0.7958 - val_loss: 0.4700 - val_accuracy: 0.7969
# Epoch 7/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4656 - accuracy: 0.7958 - val_loss: 0.4614 - val_accuracy: 0.7969
# Epoch 8/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4561 - accuracy: 0.7958 - val_loss: 0.4526 - val_accuracy: 0.7969
# Epoch 9/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4468 - accuracy: 0.7958 - val_loss: 0.4447 - val_accuracy: 0.7969
# Epoch 10/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4386 - accuracy: 0.7977 - val_loss: 0.4383 - val_accuracy: 0.8006
# Epoch 11/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4325 - accuracy: 0.8098 - val_loss: 0.4340 - val_accuracy: 0.8150
# Epoch 12/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4280 - accuracy: 0.8130 - val_loss: 0.4309 - val_accuracy: 0.8144
# Epoch 13/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4247 - accuracy: 0.8128 - val_loss: 0.4283 - val_accuracy: 0.8169
# Epoch 14/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4218 - accuracy: 0.8164 - val_loss: 0.4260 - val_accuracy: 0.8181
# Epoch 15/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4193 - accuracy: 0.8178 - val_loss: 0.4237 - val_accuracy: 0.8219
# Epoch 16/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4168 - accuracy: 0.8217 - val_loss: 0.4212 - val_accuracy: 0.8206
# Epoch 17/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4143 - accuracy: 0.8241 - val_loss: 0.4188 - val_accuracy: 0.8300
# Epoch 18/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4119 - accuracy: 0.8284 - val_loss: 0.4164 - val_accuracy: 0.8313
# Epoch 19/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4094 - accuracy: 0.8289 - val_loss: 0.4141 - val_accuracy: 0.8325
# Epoch 20/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4068 - accuracy: 0.8328 - val_loss: 0.4116 - val_accuracy: 0.8350
# Epoch 21/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4046 - accuracy: 0.8320 - val_loss: 0.4091 - val_accuracy: 0.8350
# Epoch 22/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4020 - accuracy: 0.8344 - val_loss: 0.4067 - val_accuracy: 0.8369
# Epoch 23/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3995 - accuracy: 0.8367 - val_loss: 0.4042 - val_accuracy: 0.8369
# Epoch 24/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3971 - accuracy: 0.8367 - val_loss: 0.4022 - val_accuracy: 0.8381
# Epoch 25/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3948 - accuracy: 0.8402 - val_loss: 0.3998 - val_accuracy: 0.8388
# Epoch 26/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3925 - accuracy: 0.8395 - val_loss: 0.3973 - val_accuracy: 0.8406
# Epoch 27/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3901 - accuracy: 0.8413 - val_loss: 0.3950 - val_accuracy: 0.8400
# Epoch 28/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3876 - accuracy: 0.8405 - val_loss: 0.3929 - val_accuracy: 0.8400
# Epoch 29/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3854 - accuracy: 0.8439 - val_loss: 0.3910 - val_accuracy: 0.8413
# Epoch 30/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3831 - accuracy: 0.8436 - val_loss: 0.3886 - val_accuracy: 0.8425
# Epoch 31/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3807 - accuracy: 0.8452 - val_loss: 0.3867 - val_accuracy: 0.8413
# Epoch 32/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3782 - accuracy: 0.8464 - val_loss: 0.3846 - val_accuracy: 0.8450
# Epoch 33/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3763 - accuracy: 0.8480 - val_loss: 0.3824 - val_accuracy: 0.8456
# Epoch 34/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3741 - accuracy: 0.8478 - val_loss: 0.3804 - val_accuracy: 0.8456
# Epoch 35/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3720 - accuracy: 0.8475 - val_loss: 0.3788 - val_accuracy: 0.8456
# Epoch 36/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3698 - accuracy: 0.8495 - val_loss: 0.3771 - val_accuracy: 0.8475
# Epoch 37/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3680 - accuracy: 0.8508 - val_loss: 0.3753 - val_accuracy: 0.8462
# Epoch 38/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3659 - accuracy: 0.8523 - val_loss: 0.3743 - val_accuracy: 0.8494
# Epoch 39/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3642 - accuracy: 0.8544 - val_loss: 0.3723 - val_accuracy: 0.8487
# Epoch 40/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3624 - accuracy: 0.8548 - val_loss: 0.3710 - val_accuracy: 0.8475
# Epoch 41/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3608 - accuracy: 0.8566 - val_loss: 0.3698 - val_accuracy: 0.8494
# Epoch 42/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3590 - accuracy: 0.8562 - val_loss: 0.3688 - val_accuracy: 0.8512
# Epoch 43/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3576 - accuracy: 0.8564 - val_loss: 0.3678 - val_accuracy: 0.8506
# Epoch 44/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3562 - accuracy: 0.8578 - val_loss: 0.3668 - val_accuracy: 0.8500
# Epoch 45/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3548 - accuracy: 0.8584 - val_loss: 0.3655 - val_accuracy: 0.8537
# Epoch 46/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3533 - accuracy: 0.8597 - val_loss: 0.3649 - val_accuracy: 0.8512
# Epoch 47/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3522 - accuracy: 0.8602 - val_loss: 0.3642 - val_accuracy: 0.8512
# Epoch 48/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3510 - accuracy: 0.8608 - val_loss: 0.3634 - val_accuracy: 0.8519
# Epoch 49/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3499 - accuracy: 0.8594 - val_loss: 0.3633 - val_accuracy: 0.8487
# Epoch 50/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3489 - accuracy: 0.8594 - val_loss: 0.3617 - val_accuracy: 0.8562
# Epoch 51/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3479 - accuracy: 0.8603 - val_loss: 0.3613 - val_accuracy: 0.8575
# Epoch 52/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3467 - accuracy: 0.8608 - val_loss: 0.3605 - val_accuracy: 0.8581
# Epoch 53/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3458 - accuracy: 0.8622 - val_loss: 0.3605 - val_accuracy: 0.8525
# Epoch 54/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3450 - accuracy: 0.8609 - val_loss: 0.3596 - val_accuracy: 0.8550
# Epoch 55/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3442 - accuracy: 0.8633 - val_loss: 0.3591 - val_accuracy: 0.8537
# Epoch 56/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3432 - accuracy: 0.8619 - val_loss: 0.3587 - val_accuracy: 0.8519
# Epoch 57/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3425 - accuracy: 0.8619 - val_loss: 0.3578 - val_accuracy: 0.8544
# Epoch 58/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3415 - accuracy: 0.8630 - val_loss: 0.3594 - val_accuracy: 0.8519
# Epoch 59/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3407 - accuracy: 0.8617 - val_loss: 0.3570 - val_accuracy: 0.8587
# Epoch 60/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3402 - accuracy: 0.8639 - val_loss: 0.3568 - val_accuracy: 0.8531
# Epoch 61/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3396 - accuracy: 0.8634 - val_loss: 0.3566 - val_accuracy: 0.8537
# Epoch 62/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3389 - accuracy: 0.8634 - val_loss: 0.3556 - val_accuracy: 0.8544
# Epoch 63/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3382 - accuracy: 0.8620 - val_loss: 0.3550 - val_accuracy: 0.8556
# Epoch 64/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3372 - accuracy: 0.8644 - val_loss: 0.3556 - val_accuracy: 0.8525
# Epoch 65/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3369 - accuracy: 0.8628 - val_loss: 0.3546 - val_accuracy: 0.8525
# Epoch 66/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3362 - accuracy: 0.8634 - val_loss: 0.3539 - val_accuracy: 0.8569
# Epoch 67/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3361 - accuracy: 0.8623 - val_loss: 0.3537 - val_accuracy: 0.8550
# Epoch 68/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3350 - accuracy: 0.8611 - val_loss: 0.3535 - val_accuracy: 0.8531
# Epoch 69/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3346 - accuracy: 0.8644 - val_loss: 0.3533 - val_accuracy: 0.8525
# Epoch 70/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3336 - accuracy: 0.8636 - val_loss: 0.3538 - val_accuracy: 0.8600
# Epoch 71/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3334 - accuracy: 0.8620 - val_loss: 0.3524 - val_accuracy: 0.8562
# Epoch 72/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3331 - accuracy: 0.8614 - val_loss: 0.3520 - val_accuracy: 0.8525
# Epoch 73/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3324 - accuracy: 0.8631 - val_loss: 0.3536 - val_accuracy: 0.8500
# Epoch 74/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3323 - accuracy: 0.8634 - val_loss: 0.3516 - val_accuracy: 0.8556
# Epoch 75/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3314 - accuracy: 0.8637 - val_loss: 0.3518 - val_accuracy: 0.8575
# Epoch 76/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3312 - accuracy: 0.8630 - val_loss: 0.3519 - val_accuracy: 0.8494
# Epoch 77/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3307 - accuracy: 0.8644 - val_loss: 0.3534 - val_accuracy: 0.8494
# Epoch 78/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3305 - accuracy: 0.8625 - val_loss: 0.3509 - val_accuracy: 0.8581
# Epoch 79/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3300 - accuracy: 0.8650 - val_loss: 0.3511 - val_accuracy: 0.8594
# Epoch 80/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3296 - accuracy: 0.8636 - val_loss: 0.3511 - val_accuracy: 0.8519
# Epoch 81/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3295 - accuracy: 0.8656 - val_loss: 0.3509 - val_accuracy: 0.8556
# Epoch 82/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.3291 - accuracy: 0.8639 - val_loss: 0.3504 - val_accuracy: 0.8544
# Epoch 83/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3289 - accuracy: 0.8636 - val_loss: 0.3508 - val_accuracy: 0.8537
# Epoch 84/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3284 - accuracy: 0.8642 - val_loss: 0.3503 - val_accuracy: 0.8550
# Epoch 85/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3283 - accuracy: 0.8653 - val_loss: 0.3502 - val_accuracy: 0.8562
# Epoch 86/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3280 - accuracy: 0.8644 - val_loss: 0.3502 - val_accuracy: 0.8537
# Epoch 87/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3280 - accuracy: 0.8647 - val_loss: 0.3503 - val_accuracy: 0.8537
# Epoch 88/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3274 - accuracy: 0.8650 - val_loss: 0.3499 - val_accuracy: 0.8537
# Epoch 89/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3275 - accuracy: 0.8633 - val_loss: 0.3497 - val_accuracy: 0.8556
# Epoch 90/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3272 - accuracy: 0.8647 - val_loss: 0.3503 - val_accuracy: 0.8537
# Epoch 91/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3271 - accuracy: 0.8656 - val_loss: 0.3501 - val_accuracy: 0.8581
# Epoch 92/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3267 - accuracy: 0.8653 - val_loss: 0.3502 - val_accuracy: 0.8544
# Epoch 93/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.3263 - accuracy: 0.8675 - val_loss: 0.3500 - val_accuracy: 0.8575
# Epoch 94/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3266 - accuracy: 0.8636 - val_loss: 0.3507 - val_accuracy: 0.8519
# Epoch 95/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3265 - accuracy: 0.8639 - val_loss: 0.3515 - val_accuracy: 0.8519
# Epoch 96/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3266 - accuracy: 0.8637 - val_loss: 0.3495 - val_accuracy: 0.8581
# Epoch 97/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.3262 - accuracy: 0.8652 - val_loss: 0.3496 - val_accuracy: 0.8544
# Epoch 98/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3259 - accuracy: 0.8656 - val_loss: 0.3504 - val_accuracy: 0.8519
# Epoch 99/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3258 - accuracy: 0.8658 - val_loss: 0.3497 - val_accuracy: 0.8537
# Epoch 100/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3254 - accuracy: 0.8642 - val_loss: 0.3514 - val_accuracy: 0.8575

# %%
y_pred = model.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
import numpy as np
y_pred_modified = np.where(y_pred < 0.5, 0 , 1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred_modified)
# Out:
# 0.8525

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('Value of loss function')
plt.legend(['For train data', 'For test data'])
